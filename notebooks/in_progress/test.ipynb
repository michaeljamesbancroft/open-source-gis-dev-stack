# %%
import geopandas as gpd

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine(
    "postgresql://michael:password@postgis:5432/gis"
)

# %%
query = """
SELECT
    ST_Buffer(
        ST_Point(-120, 37),
        1
    ) AS geom
"""

# %%
gdf = gpd.read_postgis(
    query,
    engine,
    geom_col="geom"
)

# %%
gdf
# Out:
#                                                 geom
# 0  POLYGON ((-119 37, -119.01921 36.80491, -119.0...
